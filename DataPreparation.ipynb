# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import os
import pandas as pd

# %%
os.chdir('/content/drive/My Drive/Bengali/data_photos/train/')

# %%
pwd
# Out:
# '/content/drive/My Drive/Bengali/data_photos/train'

# %%
#DELETING USELESS IMAGES 
os.chdir('/content/drive/My Drive/')
p ='/content/drive/My Drive/'
x = os.listdir()
x = np.asarray(x)
for i in x:
  if("image" in i):
    path = p + i
    os.remove(path)

# %%
if("image_35505.png" == os.listdir()):
  print("it is there")

# %%
os.chdir('/content/drive/My Drive/Bengali/data_photos/train/train_3')
x = os.listdir()
x = np.asarray(x)
print(x.shape)
print(x[50209])
# Out:
# (50210,)
# image_200839.png

# %%
50210 + 50210 + 50210
# Out:
# 150630

# %%
from PIL import Image

# %%
os.chdir('/content/drive/My Drive/Bengali/train_npy/')
data = np.load('train_3.npy')

# %%
data.shape
# Out:
# (50210, 137, 236)

# %%
count = 150630
for i in data:
  img = Image.fromarray(i)
  path = '/content/drive/My Drive/Bengali/data_photos/train/train_3/image_'+str(count)+'.png'
  img.save(path)
  if(count%1000 == 0):
    print(count)

  count = count + 1
# Out:
# 151000
# 152000
# 153000
# 154000
# 155000
# 156000
# 157000
# 158000
# 159000
# 160000
# 161000
# 162000
# 163000
# 164000
# 165000
# 166000
# 167000
# 168000
# 169000
# 170000
# 171000
# 172000
# 173000
# 174000
# 175000
# 176000
# 177000
# 178000
# 179000
# 180000
# 181000
# 182000
# 183000
# 184000
# 185000
# 186000
# 187000
# 188000
# 189000
# 190000
# 191000
# 192000
# 193000
# 194000
# 195000
# 196000
# 197000
# 198000
# 199000
# 200000

# %%
#CONVERTING TRAIN DATA FOLDER INTO FOLDER WITH LABELS INSIDE. THIS IS FOR DATALOADER
