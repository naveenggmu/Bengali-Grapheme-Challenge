# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import torch
import torchvision
import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import torch.nn

# %%
model = torchvision.models.resnext101_32x8d(pretrained=False, progress=True)

# %%
model.conv1 = torch.nn.Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)

# %%
model

# %%
os.chdir('/content/gdrive/My Drive/Bengali/train_npy/')

# %%
data = np.load('train_till_2.npy')

# %%
data0 = torch.Tensor(data[0])
print(type(data0))
print(data0)
# Out:
# <class 'torch.Tensor'>
# tensor([[254., 253., 252.,  ..., 254., 253., 251.],
#         [255., 253., 253.,  ..., 254., 253., 252.],
#         [255., 255., 255.,  ..., 254., 254., 253.],
#         ...,
#         [254., 254., 253.,  ..., 253., 254., 252.],
#         [254., 254., 254.,  ..., 253., 253., 252.],
#         [254., 254., 254.,  ..., 253., 253., 251.]])

# %%
print(data0.shape)
# Out:
# torch.Size([137, 236])

# %%
# transforms.functional.(img, size, interpolation=2)
# data0 = torchvision.transforms.functional.resize(data0,[137,236,1])
data0 = torch.reshape(data0,[1,1,137,236])
print(data0.shape)
# Out:
# torch.Size([1, 1, 137, 236])

# %%
model(data0)

# %%
def load_dataset():
    data_path = 'data/train/'
    train_dataset = torchvision.datasets.ImageFolder(
        root=data_path,
        transform=torchvision.transforms.ToTensor()
    )
    train_loader = torch.utils.data.DataLoader(
        train_dataset,
        batch_size=64,
        num_workers=0,
        shuffle=True
    )
    return train_loader

for batch_idx, (data, target) in enumerate(load_dataset()):
    #train network

# %%
data_path = '/content/gdrive/My Drive/Bengali/data_photos/train/train_0/'
train_dataset = torchvision.datasets.ImageFolder(root=data_path,
                                                 transform=torchvision.transforms.ToTensor())
train_loader = torch.utils.data.DataLoader(
        train_dataset,
        batch_size=64,
        num_workers=0,
        shuffle=True
    )
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-5-32044b805072> in <module>()
#       1 data_path = '/content/gdrive/My Drive/Bengali/data_photos/train/train_0/'
#       2 train_dataset = torchvision.datasets.ImageFolder(root=data_path,
# ----> 3                                                  transform=torchvision.transforms.ToTensor())
#       4 train_loader = torch.utils.data.DataLoader(
#       5         train_dataset,
#
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/folder.py in __init__(self, root, transform, target_transform, loader, is_valid_file)
#     207                                           transform=transform,
#     208                                           target_transform=target_transform,
# --> 209                                           is_valid_file=is_valid_file)
#     210         self.imgs = self.samples
#
# ...
